# %%
pip install --upgrade llama-cpp-python
# Out:
# ...
#      ---------------------------------------- 0.0/50.7 MB ? eta -:--:--
#      ---------------------------------------- 0.3/50.7 MB ? eta -:--:--
#      ---------------------------------------- 0.5/50.7 MB 1.3 MB/s eta 0:00:39
#       --------------------------------------- 1.0/50.7 MB 2.2 MB/s eta 0:00:23
#       --------------------------------------- 1.0/50.7 MB 2.2 MB/s eta 0:00:23
#      - -------------------------------------- 1.6/50.7 MB 1.7 MB/s eta 0:00:30
#      - -------------------------------------- 1.8/50.7 MB 1.8 MB/s eta 0:00:28
#      - -------------------------------------- 1.8/50.7 MB 1.8 MB/s eta 0:00:28
#      - -------------------------------------- 1.8/50.7 MB 1.8 MB/s eta 0:00:28
#      - -------------------------------------- 1.8/50.7 MB 1.8 MB/s eta 0:00:28
#      - -------------------------------------- 1.8/50.7 MB 1.8 MB/s eta 0:00:28
#      - -------------------------------------- 1.8/50.7 MB 1.8 MB/s eta 0:00:28
# ...
